# %% [markdown]
# # Scrap Proxy Ips

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = "https://free-proxy-list.net/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

ip_table = soup.find("table", class_="table table-striped table-bordered")

ip_addresses = []

rows = ip_table.find_all("tr")[1:]

# Iterate over the first 100 rows to get the IPs
for row in rows[:10]:
    ip_address = row.find("td").text
    ip_addresses.append(ip_address)

# Append IP addresses to the existing file
with open("ips.txt", "w") as file:
    for ip_address in ip_addresses:
        file.write(ip_address + "\n")

# %% [markdown]
# # Filter the valid ips

# %%
import requests
from concurrent.futures import ThreadPoolExecutor

def check_proxy(proxy):
    try:
        ip, port = proxy.split(':')
        response = requests.get('http://ipinfo.io', proxies={'http': f'http://{ip}:{port}', 'https': f'http://{ip}:{port}'}, timeout=5)
        if response.status_code == 200:
            print(f"{proxy} is valid and working")
            return proxy
        else:
            print(f"{proxy} is invalid")
            return None
    except Exception as e:
        print(f"Error checking {proxy}: {e}")
        return None

def save_to_file(proxies, filename):
    with open(filename, 'w') as f:
        for proxy in proxies:
            f.write(proxy + '\n')
    print(f"Saved {len(proxies)} valid proxies to {filename}")

def main():
    with open('ips.txt', 'r') as f:
        proxies = f.read().splitlines()

    with ThreadPoolExecutor(max_workers=20) as executor:
        valid_proxies = list(filter(None, executor.map(check_proxy, proxies)))

    print("Valid proxies:", valid_proxies)
    save_to_file(valid_proxies, 'valid-proxies.txt')

if __name__ == "__main__":
    main()
# Out:
# 154.6.98.23:3128 is valid and working
# 38.62.221.4:3128 is valid and working
# 154.6.96.102:3128 is valid and working
# 154.6.97.217:3128 is valid and working
# 154.6.97.53:3128 is valid and working
# 154.6.97.49:3128 is valid and working
# 38.62.220.194:3128 is valid and working
# 154.6.96.45:3128 is valid and working
# 154.6.98.132:3128 is valid and working
# 154.6.98.203:3128 is valid and working
# 154.6.98.148:3128 is valid and working
# 38.62.221.74:3128 is valid and working
# 154.6.99.91:3128 is valid and working
# 38.62.223.189:3128 is valid and working
# 38.62.221.140:3128 is valid and working
# 38.62.221.47:3128 is valid and working
# 38.62.222.108:3128 is valid and working
# 154.6.97.73:3128 is valid and working
# 38.62.221.155:3128 is valid and working
# 38.62.223.192:3128 is valid and working
# 154.6.98.41:3128 is valid and working
# 154.6.98.222:3128 is valid and working
# 38.62.221.49:3128 is valid and working
# 154.6.97.112:3128 is valid and working
# 38.62.221.176:3128 is valid and working
# 38.62.223.109:3128 is valid and working
# 154.6.98.101:3128 is valid and working
# 38.62.220.17:3128 is valid and working
# 38.62.220.232:3128 is valid and working
# 154.6.96.178:3128 is valid and working
# 154.6.97.22:3128 is valid and working
# 38.62.220.114:3128 is valid and working
# Error checking 154.6.99.255:3128: HTTPConnectionPool(host='154.6.99.255', port=3128): Max retries exceeded with url: http://ipinfo.io/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001B63CE42650>, 'Connection to 154.6.99.255 timed out. (connect timeout=5)'))
# Error checking 154.6.97.183:3128: HTTPConnectionPool(host='154.6.97.183', port=3128): Read timed out. (read timeout=5)Error checking 38.62.223.94:3128: HTTPConnectionPool(host='38.62.223.94', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.196:3128: HTTPConnectionPool(host='154.6.98.196', port=3128): Read timed out. (read timeout=5)
#
# Error checking 154.6.98.169:3128: HTTPConnectionPool(host='154.6.98.169', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.220.245:3128: HTTPConnectionPool(host='38.62.220.245', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.220.231:3128: HTTPConnectionPool(host='38.62.220.231', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.223.29:3128: HTTPConnectionPool(host='38.62.223.29', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.39:3128: HTTPConnectionPool(host='154.6.98.39', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.221.28:3128: HTTPConnectionPool(host='38.62.221.28', port=3128): Read timed out. (read timeout=5)
# 38.62.223.173:3128 is valid and working
# 38.62.220.211:3128 is valid and working
# 154.6.99.49:3128 is valid and working
# 38.62.221.61:3128 is valid and working
# 38.62.222.62:3128 is valid and working
# 154.6.98.167:3128 is valid and working
# 154.6.98.135:3128 is valid and working
# 38.62.221.150:3128 is valid and working
# 38.62.222.69:3128 is valid and working
# 154.6.96.158:3128 is valid and working
# 154.6.97.213:3128 is valid and working
# 38.62.220.3:3128 is valid and working
# 38.62.222.89:3128 is valid and working
# Error checking 154.6.96.187:3128: HTTPConnectionPool(host='154.6.96.187', port=3128): Read timed out. (read timeout=5)Error checking 154.6.98.9:3128: HTTPConnectionPool(host='154.6.98.9', port=3128): Read timed out. (read timeout=5)
#
# Error checking 154.6.97.230:3128: HTTPConnectionPool(host='154.6.97.230', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.222.254:3128: HTTPConnectionPool(host='38.62.222.254', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.97.110:3128: HTTPConnectionPool(host='154.6.97.110', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.96.208:3128: HTTPConnectionPool(host='154.6.96.208', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.97.10:3128: HTTPConnectionPool(host='154.6.97.10', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.195:3128: HTTPConnectionPool(host='154.6.98.195', port=3128): Read timed out. (read timeout=5)
# 38.62.223.137:3128 is valid and working
# 38.62.222.169:3128 is valid and working
# 154.6.97.188:3128 is valid and working
# 154.6.99.233:3128 is valid and working
# 154.6.98.247:3128 is valid and working
# 38.62.220.104:3128 is valid and working
# 154.6.97.42:3128 is valid and working
# 154.6.99.81:3128 is valid and working
# 154.6.96.197:3128 is valid and working
# 38.62.223.128:3128 is valid and working
# 38.62.223.187:3128 is valid and working
# 38.62.220.202:3128 is valid and working
# 154.6.96.121:3128 is valid and working
# 154.6.99.215:3128 is valid and working
# 38.62.223.141:3128 is valid and working
# 154.6.96.78:3128 is valid and working
# 154.6.99.105:3128 is valid and working
# 154.6.98.125:3128 is valid and working
# 154.6.98.166:3128 is valid and working
# Error checking 154.6.98.42:3128: HTTPConnectionPool(host='154.6.98.42', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.190:3128: HTTPConnectionPool(host='154.6.98.190', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.108:3128: HTTPConnectionPool(host='154.6.98.108', port=3128): Read timed out. (read timeout=5)Error checking 38.62.223.171:3128: HTTPConnectionPool(host='38.62.223.171', port=3128): Read timed out. (read timeout=5)
#
# Error checking 154.6.96.139:3128: HTTPConnectionPool(host='154.6.96.139', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.96.231:3128: HTTPConnectionPool(host='154.6.96.231', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.222.44:3128: HTTPConnectionPool(host='38.62.222.44', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.221.64:3128: HTTPConnectionPool(host='38.62.221.64', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.99.57:3128: HTTPConnectionPool(host='154.6.99.57', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.222.79:3128: HTTPConnectionPool(host='38.62.222.79', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.223.231:3128: HTTPConnectionPool(host='38.62.223.231', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.96.161:3128: HTTPConnectionPool(host='154.6.96.161', port=3128): Read timed out. (read timeout=5)
# Error checking 154.6.98.205:3128: HTTPConnectionPool(host='154.6.98.205', port=3128): Read timed out. (read timeout=5)Error checking 154.6.97.200:3128: HTTPConnectionPool(host='154.6.97.200', port=3128): Read timed out. (read timeout=5)
#
# Error checking 154.6.96.196:3128: HTTPConnectionPool(host='154.6.96.196', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.221.46:3128: HTTPConnectionPool(host='38.62.221.46', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.221.174:3128: HTTPConnectionPool(host='38.62.221.174', port=3128): Read timed out. (read timeout=5)
# Error checking 38.62.222.67:3128: HTTPConnectionPool(host='38.62.222.67', port=3128): Read timed out. (read timeout=5)
# Valid proxies: ['154.6.97.49:3128', '154.6.97.217:3128', '154.6.96.45:3128', '154.6.96.102:3128', '38.62.221.4:3128', '38.62.220.194:3128', '154.6.98.23:3128', '154.6.98.132:3128', '154.6.97.53:3128', '154.6.98.203:3128', '38.62.221.74:3128', '154.6.99.91:3128', '38.62.221.47:3128', '154.6.98.148:3128', '38.62.223.189:3128', '38.62.221.155:3128', '38.62.221.140:3128', '154.6.98.41:3128', '154.6.97.73:3128', '38.62.222.108:3128', '38.62.223.192:3128', '154.6.98.222:3128', '38.62.221.49:3128', '154.6.97.112:3128', '38.62.221.176:3128', '38.62.223.109:3128', '154.6.98.101:3128', '38.62.220.17:3128', '38.62.220.232:3128', '154.6.96.178:3128', '154.6.97.22:3128', '38.62.220.114:3128', '38.62.220.211:3128', '38.62.223.173:3128', '154.6.99.49:3128', '154.6.98.135:3128', '38.62.222.62:3128', '38.62.221.61:3128', '154.6.97.213:3128', '154.6.96.158:3128', '154.6.98.167:3128', '38.62.221.150:3128', '38.62.220.3:3128', '38.62.222.69:3128', '38.62.222.89:3128', '38.62.223.137:3128', '38.62.222.169:3128', '154.6.98.247:3128', '154.6.99.233:3128', '154.6.97.188:3128', '38.62.220.104:3128', '154.6.97.42:3128', '154.6.99.81:3128', '38.62.223.128:3128', '154.6.96.197:3128', '38.62.223.187:3128', '38.62.220.202:3128', '154.6.96.121:3128', '154.6.99.215:3128', '38.62.223.141:3128', '154.6.96.78:3128', '154.6.99.105:3128', '154.6.98.125:3128', '154.6.98.166:3128']
# Saved 64 valid proxies to valid-proxies.txt

# %% [markdown]
# # Extract the links of the articles from pagination

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Function to read proxy IPs from a file
def read_proxy_ips(file_path):
    with open(file_path, "r") as file:
        proxy_ips = [line.strip() for line in file if line.strip()]
    return proxy_ips

# Function to fetch article links from a page
def fetch_article_links(url, proxy):
    try:
        response = requests.get(url, proxies={"http": proxy, "https": proxy}, timeout=5)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")
            article_section = soup.find("section", class_="editorial river")
            if article_section:
                article_links = []
                for article_element in article_section.find_all("a", class_="card-item__link"):
                    article_link = article_element.get("href")
                    full_article_link = "https://www.gamespot.com" + article_link
                    article_links.append(full_article_link)
                return article_links
    except Exception as e:
        print(f"Error fetching article links from {url} using proxy {proxy}: {e}")
    return []

#Main function to fetch article links from multiple pages with pagination
def main():
    base_url = "https://www.gamespot.com/games/reviews/?page={}"
    proxy_ips = read_proxy_ips("valid-proxies.txt")  #Assuming proxy IPs are stored in validIps.txt

    with open("article_links.csv", "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Article Link", "Proxy IP"])

        for page in range(1, 126):  
            print(f"Fetching page {page}...")
            page_url = base_url.format(page)
            for proxy in proxy_ips:
                article_links = fetch_article_links(page_url, proxy)
                for article_link in article_links:
                    writer.writerow([article_link, proxy])
                if article_links:  
                    break
            time.sleep(2)  

if __name__ == "__main__":
    main()
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# Fetching page 21...
# Fetching page 22...
# Fetching page 23...
# Fetching page 24...
# Fetching page 25...
# Fetching page 26...
# Fetching page 27...
# Fetching page 28...
# Fetching page 29...
# Fetching page 30...
# Fetching page 31...
# Fetching page 32...
# Fetching page 33...
# Fetching page 34...
# Fetching page 35...
# Fetching page 36...
# Fetching page 37...
# Fetching page 38...
# Fetching page 39...
# Fetching page 40...
# Fetching page 41...
# Fetching page 42...
# Fetching page 43...
# Fetching page 44...
# Fetching page 45...
# Fetching page 46...
# Fetching page 47...
# Fetching page 48...
# Fetching page 49...
# Fetching page 50...
# Fetching page 51...
# Fetching page 52...
# Fetching page 53...
# Fetching page 54...
# Fetching page 55...
# Fetching page 56...
# Fetching page 57...
# Fetching page 58...
# Fetching page 59...
# Fetching page 60...
# Fetching page 61...
# Fetching page 62...
# Fetching page 63...
# Fetching page 64...
# Fetching page 65...
# Fetching page 66...
# Fetching page 67...
# Fetching page 68...
# Fetching page 69...
# Fetching page 70...
# Fetching page 71...
# Fetching page 72...
# Fetching page 73...
# Fetching page 74...
# Fetching page 75...
# Fetching page 76...
# Fetching page 77...
# Fetching page 78...
# Fetching page 79...
# Fetching page 80...
# Fetching page 81...
# Fetching page 82...
# Fetching page 83...
# Fetching page 84...
# Fetching page 85...
# Fetching page 86...
# Fetching page 87...
# Fetching page 88...
# Fetching page 89...
# Fetching page 90...
# Fetching page 91...
# Fetching page 92...
# Fetching page 93...
# Fetching page 94...
# Fetching page 95...
# Fetching page 96...
# Fetching page 97...
# Fetching page 98...
# Fetching page 99...
# Fetching page 100...
# Fetching page 101...
# Fetching page 102...
# Fetching page 103...
# Fetching page 104...
# Fetching page 105...
# Fetching page 106...
# Fetching page 107...
# Fetching page 108...
# Fetching page 109...
# Fetching page 110...
# Fetching page 111...
# Fetching page 112...
# Fetching page 113...
# Fetching page 114...
# Fetching page 115...
# Fetching page 116...
# Fetching page 117...
# Fetching page 118...
# Fetching page 119...
# Fetching page 120...
# Fetching page 121...
# Fetching page 122...
# Fetching page 123...
# Fetching page 124...
# Fetching page 125...

# %% [markdown]
# # Sample of a single page

# %%
import requests
from bs4 import BeautifulSoup

# Website link
url = "https://www.gamespot.com/reviews/like-a-dragon-gaiden-review-the-man-who-cant-escape-the-yakuza/1900-6418151/"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, "html.parser")

    # Extract the URL of the image
    image_url = soup.find("div", class_="kubrick-lead")["style"].split("url(")[1].split(")")[0]

    # Extract the title
    title = soup.find("h1", class_="kubrick-info__title").text.strip()

    # Extract the content represented by paragraph tags within the specified section
    article_section = soup.find("section", class_="article-body typography-format")
    paragraphs = article_section.find_all("p")
    content = "\n".join([p.get_text(strip=True) for p in paragraphs])

    # Extract review rating
    review_rating_container = soup.find("div", class_="review-breakdown__score-container")
    review_rating = review_rating_container.find("div", class_="review-ring-score__score").text.strip()

    # Extract the good and bad aspects
    review_breakdown = soup.find("div", class_="review-breakdown__lists")
    good_aspects = [li.text.strip() for li in review_breakdown.find("ul", class_="review-breakdown__list").find_all("li")]
    bad_aspects = [li.text.strip() for li in review_breakdown.find_all("ul", class_="review-breakdown__list")[1].find_all("li")]

    print("Image URL:", image_url)
    print("Title:", title)
    print("Content:")
    print(content)
    print("Review Rating:", review_rating)
    print("Good Aspects:", good_aspects)
    print("Bad Aspects:", bad_aspects)
else:
    print("Failed to load the page. Status code:", response.status_code)

# %% [markdown]
# # Scrapping 2000+ Articles on gaming reviews

# %%
import csv
import requests
from bs4 import BeautifulSoup
import random
import time

# Function to scrape article details
def scrape_article_details(url, proxy):
    try:
        proxies = {"http": proxy, "https": proxy}
        response = requests.get(url, proxies=proxies)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")

            #extracting the article
            image_url = soup.find("div", class_="kubrick-lead")["style"].split("url(")[1].split(")")[0]

            #extracting the articles
            title = soup.find("h1", class_="kubrick-info__title").text.strip()

            #extracting all the pargraphs within the article body only
            article_section = soup.find("section", class_="article-body typography-format")
            paragraphs = article_section.find_all("p")
            content = "\n".join([p.get_text(strip=True) for p in paragraphs])

            # Extract review rating
            review_rating_container = soup.find("div", class_="review-breakdown__score-container")
            review_rating = review_rating_container.find("div", class_="review-ring-score__score").text.strip()

            # Extract the good and bad aspects
            review_breakdown = soup.find("div", class_="review-breakdown__lists")
            good_aspects = [li.text.strip() for li in review_breakdown.find("ul", class_="review-breakdown__list").find_all("li")]
            bad_aspects = [li.text.strip() for li in review_breakdown.find_all("ul", class_="review-breakdown__list")[1].find_all("li")]

            # Return the scraped data
            return {
                "Proxy":proxies,
                "URL": url,
                "Image URL": image_url,
                "Title": title,
                "Content": content,
                "Review Rating": review_rating,
                "Good Aspects": good_aspects,
                "Bad Aspects": bad_aspects
            }
    except Exception as e:
        print(f"An error occurred with proxy {proxy} while scraping {url}: {str(e)}")
        return None

#Function to rotate proxy IPs
def rotate_proxies(proxies):
    while True:
        yield random.choice(proxies)

# Function to scrape article details using rotating proxies
def scrape_with_rotating_proxies(article_links, proxy_ips):
    with open("gaming_reviews.csv", mode='w', newline='', encoding='utf-8') as file:
        fieldnames = ["Proxy","URL", "Image URL", "Title", "Content", "Review Rating", "Good Aspects", "Bad Aspects"]
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        count = 0
        proxy_rotator = rotate_proxies(proxy_ips)
        for article_link in article_links:
            proxy = next(proxy_rotator)
            scraped_data = scrape_article_details(article_link, proxy)
            if scraped_data:
                writer.writerow(scraped_data)
                print(f"{count } Scraped data for {article_link} saved to 'scraped_data.csv'.",proxy)
                count+=1
                time.sleep(2)  #Delay
            else:
                print(f"Failed to scrape data for {article_link}.")

#reading links from the csv file
article_links = []
with open("article_links.csv", mode='r', newline='', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        article_links.append(row["Article Link"])

#reading the valid ips
proxy_ips = []
with open("valid-proxies.txt", mode='r', newline='', encoding='utf-8') as file:
    for line in file:
        proxy_ips.append(line.strip())

# Scrape article details using rotating proxies
scrape_with_rotating_proxies(article_links, proxy_ips)
# Out:
# 0 Scraped data for https://www.gamespot.com/reviews/tekken-8-review-the-heat-of-battle/1900-6418169/ saved to 'scraped_data.csv'. 38.62.222.89:3128
# 1 Scraped data for https://www.gamespot.com/reviews/silent-hill-the-short-message-review-in-my-restless-dreams-i-flee-that-town/1900-6418173/ saved to 'scraped_data.csv'. 154.6.98.169:3128
# 2 Scraped data for https://www.gamespot.com/reviews/persona-3-reload-review-burn-your-dread/1900-6418171/ saved to 'scraped_data.csv'. 154.6.96.178:3128
# 3 Scraped data for https://www.gamespot.com/reviews/like-a-dragon-infinite-wealth-review-the-things-money-cant-buy/1900-6418170/ saved to 'scraped_data.csv'. 38.62.221.150:3128
# 4 Scraped data for https://www.gamespot.com/reviews/another-code-recollection-full-of-mysteries/1900-6418168/ saved to 'scraped_data.csv'. 154.6.96.197:3128
# 5 Scraped data for https://www.gamespot.com/reviews/prince-of-persia-the-lost-crown-review-crowning-achievement/1900-6418167/ saved to 'scraped_data.csv'. 38.62.221.140:3128
# 6 Scraped data for https://www.gamespot.com/reviews/the-finals-review-an-explosive-game-show/1900-6418164/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# 7 Scraped data for https://www.gamespot.com/reviews/arizona-sunshine-2-review-the-walking-shred/1900-6418163/ saved to 'scraped_data.csv'. 154.6.98.132:3128
# 8 Scraped data for https://www.gamespot.com/reviews/avatar-frontiers-of-pandora-review-the-good-blue-man-group/1900-6418162/ saved to 'scraped_data.csv'. 154.6.96.231:3128
# 9 Scraped data for https://www.gamespot.com/reviews/thirsty-suitors-review-im-jala-goddamn-jayaratne/1900-6418160/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# 10 Scraped data for https://www.gamespot.com/reviews/cod-modern-warfare-3-mp-and-zombies-review-selling-nostalgia/1900-6418159/ saved to 'scraped_data.csv'. 154.6.98.101:3128
# 11 Scraped data for https://www.gamespot.com/reviews/persona-5-tactica-review-vive-la-persona/1900-6418157/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 12 Scraped data for https://www.gamespot.com/reviews/super-mario-rpg-review-an-authentic-ode-to-a-classic/1900-6418158/ saved to 'scraped_data.csv'. 38.62.221.47:3128
# 13 Scraped data for https://www.gamespot.com/reviews/nickelodeon-all-star-brawl-2-review-more-than-a-rerun/1900-6418156/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# 14 Scraped data for https://www.gamespot.com/reviews/assassins-creed-mirage-review-back-to-basics/1900-6418126/ saved to 'scraped_data.csv'. 154.6.98.167:3128
# 15 Scraped data for https://www.gamespot.com/reviews/you-will-die-here-tonight-review-empty-residence/1900-6418153/ saved to 'scraped_data.csv'. 38.62.223.192:3128
# 16 Scraped data for https://www.gamespot.com/reviews/like-a-dragon-gaiden-review-the-man-who-cant-escape-the-yakuza/1900-6418151/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 17 Scraped data for https://www.gamespot.com/reviews/sonic-superstars-review-reaching-for-stars/1900-6418139/ saved to 'scraped_data.csv'. 154.6.96.197:3128
# 18 Scraped data for https://www.gamespot.com/reviews/warioware-move-it-review-i-am-merely-okay-to-move-it-move-it/1900-6418146/ saved to 'scraped_data.csv'. 154.6.99.233:3128
# 19 Scraped data for https://www.gamespot.com/reviews/call-of-duty-modern-warfare-3-campaign-review-return-of-the-makarov/1900-6418152/ saved to 'scraped_data.csv'. 38.62.221.49:3128
# 20 Scraped data for https://www.gamespot.com/reviews/ghostrunner-2-review-delicate-balance/1900-6418150/ saved to 'scraped_data.csv'. 154.6.98.132:3128
# 21 Scraped data for https://www.gamespot.com/reviews/the-talos-principle-2-review-machine-learning/1900-6418148/ saved to 'scraped_data.csv'. 38.62.223.94:3128
# 22 Scraped data for https://www.gamespot.com/reviews/robocop-rogue-city-review-id-buy-that-for-a-dollar/1900-6418149/ saved to 'scraped_data.csv'. 154.6.96.161:3128
# 23 Scraped data for https://www.gamespot.com/reviews/star-ocean-the-second-story-r-review-back-to-the-future/1900-6418147/ saved to 'scraped_data.csv'. 154.6.98.41:3128
# 24 Scraped data for https://www.gamespot.com/reviews/alan-wake-2-review-a-miracle-illuminated/1900-6418143/ saved to 'scraped_data.csv'. 154.6.96.196:3128
# 25 Scraped data for https://www.gamespot.com/reviews/metal-gear-solid-master-collection-vol-1-kept-you-waiting-huh/1900-6418142/ saved to 'scraped_data.csv'. 154.6.97.53:3128
# 26 Scraped data for https://www.gamespot.com/reviews/payday-3-review-turning-up-the-heat/1900-6418140/ saved to 'scraped_data.csv'. 154.6.97.73:3128
# 27 Scraped data for https://www.gamespot.com/reviews/hot-wheels-unleashed-2-turbocharged-review-2-hot-2-wheels/1900-6418137/ saved to 'scraped_data.csv'. 38.62.222.62:3128
# 28 Scraped data for https://www.gamespot.com/reviews/super-mario-bros-wonder-review-a-badge-of-honor/1900-6418136/ saved to 'scraped_data.csv'. 38.62.220.104:3128
# 29 Scraped data for https://www.gamespot.com/reviews/marvels-spider-man-2-review-web-warriors/1900-6418134/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# 30 Scraped data for https://www.gamespot.com/reviews/lords-of-the-fallen-review-dark-slog/1900-6418133/ saved to 'scraped_data.csv'. 38.62.221.174:3128
# 31 Scraped data for https://www.gamespot.com/reviews/hellboy-web-of-wyrd-review-a-way-with-wyrds/1900-6418135/ saved to 'scraped_data.csv'. 154.6.99.49:3128
# 32 Scraped data for https://www.gamespot.com/reviews/forza-motorsport-review/1900-6418125/ saved to 'scraped_data.csv'. 38.62.220.232:3128
# 33 Scraped data for https://www.gamespot.com/reviews/baldurs-gate-3-review-let-freedom-reign/1900-6418131/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# 34 Scraped data for https://www.gamespot.com/reviews/wild-card-football-review-undrafted/1900-6418132/ saved to 'scraped_data.csv'. 154.6.96.102:3128
# 35 Scraped data for https://www.gamespot.com/reviews/cocoon-review-a-bugs-strife/1900-6418123/ saved to 'scraped_data.csv'. 38.62.220.114:3128
# 36 Scraped data for https://www.gamespot.com/reviews/detective-pikachu-returns-review-soft-boiled/1900-6418128/ saved to 'scraped_data.csv'. 154.6.97.200:3128
# 37 Scraped data for https://www.gamespot.com/reviews/ea-sports-fc-24-review-new-name-same-game/1900-6418129/ saved to 'scraped_data.csv'. 38.62.223.171:3128
# 38 Scraped data for https://www.gamespot.com/reviews/resident-evil-4-separate-ways-dlc-review-where-does-she-get-those-wonderful-toys/1900-6418122/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 39 Scraped data for https://www.gamespot.com/reviews/el-paso-elsewhere-review-you-keep-going/1900-6418120/ saved to 'scraped_data.csv'. 154.6.96.45:3128
# 40 Scraped data for https://www.gamespot.com/reviews/pokemon-scarlet-and-violet-the-hidden-treasure-of-area-zero-review-in-progress/1900-6418119/ saved to 'scraped_data.csv'. 38.62.220.245:3128
# 41 Scraped data for https://www.gamespot.com/reviews/nba-2k24-review-breaking-ankles-breaking-banks/1900-6418117/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 42 Scraped data for https://www.gamespot.com/reviews/cyberpunk-2077-phantom-liberty-review-the-songbird-sings/1900-6418116/ saved to 'scraped_data.csv'. 154.6.99.233:3128
# 43 Scraped data for https://www.gamespot.com/reviews/mortal-kombat-1-review-new-era-familiar-kombat/1900-6418115/ saved to 'scraped_data.csv'. 38.62.223.137:3128
# 44 Scraped data for https://www.gamespot.com/reviews/lies-of-p-review-no-strings-attached/1900-6418114/ saved to 'scraped_data.csv'. 38.62.221.150:3128
# 45 Scraped data for https://www.gamespot.com/reviews/sea-of-stars-review-playing-with-power/1900-6418113/ saved to 'scraped_data.csv'. 154.6.99.105:3128
# 46 Scraped data for https://www.gamespot.com/reviews/starfield-review-to-infinity-but-not-beyond/1900-6418110/ saved to 'scraped_data.csv'. 38.62.223.109:3128
# 47 Scraped data for https://www.gamespot.com/reviews/armored-core-6-fires-of-rubicon-review-mechlike/1900-6418109/ saved to 'scraped_data.csv'. 154.6.99.57:3128
# 48 Scraped data for https://www.gamespot.com/reviews/fort-solis-review-strife-on-mars/1900-6418105/ saved to 'scraped_data.csv'. 38.62.220.245:3128
# 49 Scraped data for https://www.gamespot.com/reviews/immortals-of-aveum-review-run-and-gun/1900-6418107/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 50 Scraped data for https://www.gamespot.com/reviews/madden-nfl-24-review-one-yard-forward-two-yards-back/1900-6418106/ saved to 'scraped_data.csv'. 38.62.223.187:3128
# 51 Scraped data for https://www.gamespot.com/reviews/blasphemous-2-review-unholy-pilgrimage/1900-6418101/ saved to 'scraped_data.csv'. 38.62.221.46:3128
# 52 Scraped data for https://www.gamespot.com/reviews/shadow-gambit-the-cursed-crew-review-spectacul-arrrr/1900-6418103/ saved to 'scraped_data.csv'. 38.62.221.47:3128
# 53 Scraped data for https://www.gamespot.com/reviews/the-texas-chain-saw-massacre-review-thrill-of-the-hunt/1900-6418102/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 54 Scraped data for https://www.gamespot.com/reviews/wrestlequest-review-not-the-excellence-of-execution/1900-6418100/ saved to 'scraped_data.csv'. 38.62.223.189:3128
# 55 Scraped data for https://www.gamespot.com/reviews/stray-gods-a-roleplaying-musical-review-worthy-of-an-encore/1900-6418099/ saved to 'scraped_data.csv'. 154.6.97.183:3128
# 56 Scraped data for https://www.gamespot.com/reviews/the-expanse-a-telltale-series-review-choices-that-matter/1900-6418098/ saved to 'scraped_data.csv'. 154.6.98.108:3128
# 57 Scraped data for https://www.gamespot.com/reviews/exoprimal-review-prehistoric-warfare/1900-6418097/ saved to 'scraped_data.csv'. 38.62.220.202:3128
# 58 Scraped data for https://www.gamespot.com/reviews/venba-review-tourist-to-your-own-culture/1900-6418096/ saved to 'scraped_data.csv'. 38.62.222.169:3128
# 59 Scraped data for https://www.gamespot.com/reviews/disney-illusion-island-review/1900-6418094/ saved to 'scraped_data.csv'. 38.62.223.192:3128
# 60 Scraped data for https://www.gamespot.com/reviews/remnant-2-review-what-the-dog-doing/1900-6418092/ saved to 'scraped_data.csv'. 154.6.96.231:3128
# 61 Scraped data for https://www.gamespot.com/reviews/pikmin-4-review-veggie-might/1900-6418090/ saved to 'scraped_data.csv'. 38.62.222.169:3128
# 62 Scraped data for https://www.gamespot.com/reviews/viewfinder-review-one-perfect-shot/1900-6418089/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 63 Scraped data for https://www.gamespot.com/reviews/oxenfree-2-lost-signals-review-unnerving-static/1900-6418088/ saved to 'scraped_data.csv'. 38.62.220.232:3128
# 64 Scraped data for https://www.gamespot.com/reviews/master-detective-archives-rain-code-review-blame-it-on-the-rain/1900-6418087/ saved to 'scraped_data.csv'. 38.62.222.62:3128
# 65 Scraped data for https://www.gamespot.com/reviews/aliens-dark-descent-review-theyre-in-the-walls/1900-6418085/ saved to 'scraped_data.csv'. 38.62.221.46:3128
# An error occurred with proxy 154.6.98.23:3128 while scraping https://www.gamespot.com/reviews/story-of-seasons-a-wonderful-life-review-putting-the-past-in-pastoral/1900-6418084/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/story-of-seasons-a-wonderful-life-review-putting-the-past-in-pastoral/1900-6418084/.
# 66 Scraped data for https://www.gamespot.com/reviews/crash-team-rumble-review-a-fresh-spin/1900-6418083/ saved to 'scraped_data.csv'. 154.6.98.167:3128
# 67 Scraped data for https://www.gamespot.com/reviews/aew-fight-forever-review-a-midcard-debut/1900-6418082/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# 68 Scraped data for https://www.gamespot.com/reviews/final-fantasy-16-review-on-its-own-terms/1900-6418081/ saved to 'scraped_data.csv'. 154.6.96.187:3128
# 69 Scraped data for https://www.gamespot.com/reviews/layers-of-fear-2023-review-delusions-of-grandeur/1900-6418080/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# An error occurred with proxy 154.6.99.255:3128 while scraping https://www.gamespot.com/reviews/street-fighter-6-review-battle-hardened/1900-6418073/: HTTPSConnectionPool(host='www.gamespot.com', port=443): Max retries exceeded with url: /reviews/street-fighter-6-review-battle-hardened/1900-6418073/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000027D240B43D0>, 'Connection to 154.6.99.255 timed out. (connect timeout=None)'))
# Failed to scrape data for https://www.gamespot.com/reviews/street-fighter-6-review-battle-hardened/1900-6418073/.
# 70 Scraped data for https://www.gamespot.com/reviews/amnesia-the-bunker-review-shellshocked/1900-6418075/ saved to 'scraped_data.csv'. 38.62.223.173:3128
# 71 Scraped data for https://www.gamespot.com/reviews/diablo-4-review-mother-knows-best/1900-6418072/ saved to 'scraped_data.csv'. 38.62.222.89:3128
# 72 Scraped data for https://www.gamespot.com/reviews/humanity-review-what-is-a-man/1900-6418071/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 73 Scraped data for https://www.gamespot.com/reviews/the-lord-of-the-rings-gollum-review-we-dont-wants-it-we-dont-needs-it/1900-6418070/ saved to 'scraped_data.csv'. 154.6.96.78:3128
# 74 Scraped data for https://www.gamespot.com/reviews/lego-2k-drive-review-oh-snap/1900-6418067/ saved to 'scraped_data.csv'. 154.6.98.41:3128
# 75 Scraped data for https://www.gamespot.com/reviews/after-us-review-abstract-dystopia/1900-6418068/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 76 Scraped data for https://www.gamespot.com/reviews/warhammer-40000-boltgun-review-purge-and-tear/1900-6418066/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 77 Scraped data for https://www.gamespot.com/reviews/the-last-case-of-benedict-fox-review-fair-deal/1900-6418064/ saved to 'scraped_data.csv'. 154.6.96.102:3128
# 78 Scraped data for https://www.gamespot.com/reviews/the-legend-of-zelda-tears-of-the-kingdom-review/1900-6418063/ saved to 'scraped_data.csv'. 38.62.220.211:3128
# 79 Scraped data for https://www.gamespot.com/reviews/redfall-review-half-staked/1900-6418062/ saved to 'scraped_data.csv'. 154.6.98.247:3128
# 80 Scraped data for https://www.gamespot.com/reviews/star-wars-jedi-survivor-review-fear-itself/1900-6418060/ saved to 'scraped_data.csv'. 154.6.96.158:3128
# 81 Scraped data for https://www.gamespot.com/reviews/the-mageseeker-a-league-of-legends-story-review-magic-in-the-air/1900-6418059/ saved to 'scraped_data.csv'. 154.6.96.45:3128
# 82 Scraped data for https://www.gamespot.com/reviews/horizon-forbidden-west-burning-shores-review/1900-6418058/ saved to 'scraped_data.csv'. 154.6.98.9:3128
# 83 Scraped data for https://www.gamespot.com/reviews/minecraft-legends-review-tides-of-war/1900-6418057/ saved to 'scraped_data.csv'. 38.62.221.176:3128
# 84 Scraped data for https://www.gamespot.com/reviews/advance-wars-12-re-boot-camp-review-war-games/1900-6418056/ saved to 'scraped_data.csv'. 154.6.97.53:3128
# 85 Scraped data for https://www.gamespot.com/reviews/dead-island-2-review-eat-the-rich/1900-6418055/ saved to 'scraped_data.csv'. 154.6.98.166:3128
# 86 Scraped data for https://www.gamespot.com/reviews/tron-identity-review-gone-in-60-millicycles/1900-6418054/ saved to 'scraped_data.csv'. 38.62.221.28:3128
# 87 Scraped data for https://www.gamespot.com/reviews/ea-sports-pga-tour-review-hit-the-links/1900-6418053/ saved to 'scraped_data.csv'. 154.6.97.73:3128
# An error occurred with proxy 154.6.98.148:3128 while scraping https://www.gamespot.com/reviews/storyteller-review-tale-as-old-as-time/1900-6418052/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/storyteller-review-tale-as-old-as-time/1900-6418052/.
# 88 Scraped data for https://www.gamespot.com/reviews/the-last-of-us-part-i-ps5-and-pc-review-desolation-row/1900-6417949/ saved to 'scraped_data.csv'. 38.62.222.254:3128
# 89 Scraped data for https://www.gamespot.com/reviews/mlb-the-show-23-review-grand-slam/1900-6418050/ saved to 'scraped_data.csv'. 154.6.97.230:3128
# 90 Scraped data for https://www.gamespot.com/reviews/dredge-review-grant-us-eels/1900-6418049/ saved to 'scraped_data.csv'. 38.62.222.108:3128
# 91 Scraped data for https://www.gamespot.com/reviews/wwe-2k23-review-head-of-the-table/1900-6418048/ saved to 'scraped_data.csv'. 154.6.98.195:3128
# 92 Scraped data for https://www.gamespot.com/reviews/resident-evil-4-remake-review-stranga-stranga-now-thats-a-remake/1900-6418047/ saved to 'scraped_data.csv'. 38.62.223.173:3128
# 93 Scraped data for https://www.gamespot.com/reviews/bayonetta-origins-cereza-and-the-lost-demon-malice-in-wonderland/1900-6418045/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# 94 Scraped data for https://www.gamespot.com/reviews/destiny-2-lightfall-review-deft-stranding/1900-6418042/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 95 Scraped data for https://www.gamespot.com/reviews/dead-cells-return-to-castlevania-review-pay-me-tribute/1900-6418041/ saved to 'scraped_data.csv'. 154.6.98.166:3128
# 96 Scraped data for https://www.gamespot.com/reviews/wo-long-fallen-dynasty-review-souls-like-of-the-three-kingdoms/1900-6418040/ saved to 'scraped_data.csv'. 154.6.97.112:3128
# 97 Scraped data for https://www.gamespot.com/reviews/octopath-traveler-2-review-go-your-own-way/1900-6418036/ saved to 'scraped_data.csv'. 38.62.222.62:3128
# 98 Scraped data for https://www.gamespot.com/reviews/tales-of-symphonia-remastered-review-a-classic-regenerated/1900-6418037/ saved to 'scraped_data.csv'. 38.62.221.150:3128
# 99 Scraped data for https://www.gamespot.com/reviews/kirbys-return-to-dream-land-deluxe-review-kirb-your-enthusiasm/1900-6418034/ saved to 'scraped_data.csv'. 38.62.223.189:3128
# 100 Scraped data for https://www.gamespot.com/reviews/hogwarts-legacy-review-sleight-of-hand/1900-6418032/ saved to 'scraped_data.csv'. 154.6.98.203:3128
# 101 Scraped data for https://www.gamespot.com/reviews/atomic-heart-review-crispy-critters/1900-6418033/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 102 Scraped data for https://www.gamespot.com/reviews/like-a-dragon-ishin-review-rewriting-history/1900-6418031/ saved to 'scraped_data.csv'. 38.62.220.211:3128
# 103 Scraped data for https://www.gamespot.com/reviews/wild-hearts-review-build-me-up/1900-6418030/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 104 Scraped data for https://www.gamespot.com/reviews/horizon-call-of-the-mountain-review-new-heights/1900-6418028/ saved to 'scraped_data.csv'. 154.6.98.195:3128
# 105 Scraped data for https://www.gamespot.com/reviews/theatrhythm-final-bar-line-review-greatest-hits/1900-6418029/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 106 Scraped data for https://www.gamespot.com/reviews/returnal-review-pc-update-live-die-repeat/1900-6417669/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# 107 Scraped data for https://www.gamespot.com/reviews/tomb-raider-reloaded-review-plenty-of-firepower/1900-6418026/ saved to 'scraped_data.csv'. 38.62.223.94:3128
# 108 Scraped data for https://www.gamespot.com/reviews/valiant-hearts-coming-home-review-in-the-trenches/1900-6418024/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# 109 Scraped data for https://www.gamespot.com/reviews/hi-fi-rush-review-good-vibes-only/1900-6418023/ saved to 'scraped_data.csv'. 38.62.223.137:3128
# 110 Scraped data for https://www.gamespot.com/reviews/persona-4-golden-review-stay-golden/1900-6400482/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 111 Scraped data for https://www.gamespot.com/reviews/shin-megami-tensei-persona-3-portable-review/1900-6175580/ saved to 'scraped_data.csv'. 154.6.96.161:3128
# 112 Scraped data for https://www.gamespot.com/reviews/world-of-warcraft-dragonflight-review-who-says-you-cant-go-home/1900-6418011/ saved to 'scraped_data.csv'. 154.6.96.161:3128
# 113 Scraped data for https://www.gamespot.com/reviews/spongebob-squarepants-the-cosmic-shake-review-f-u-n/1900-6418022/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 114 Scraped data for https://www.gamespot.com/reviews/dead-space-remake-review-hits-the-marker/1900-6418021/ saved to 'scraped_data.csv'. 38.62.221.49:3128
# 115 Scraped data for https://www.gamespot.com/reviews/season-a-letter-to-the-future-review-the-meditation-game/1900-6418020/ saved to 'scraped_data.csv'. 154.6.96.197:3128
# 116 Scraped data for https://www.gamespot.com/reviews/forspoken-review-forsaken/1900-6418019/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# 117 Scraped data for https://www.gamespot.com/reviews/one-piece-odyssey-review-filler-arc/1900-6418018/ saved to 'scraped_data.csv'. 154.6.97.213:3128
# 118 Scraped data for https://www.gamespot.com/reviews/fire-emblem-engage-review-rings-of-power/1900-6418017/ saved to 'scraped_data.csv'. 38.62.221.74:3128
# 119 Scraped data for https://www.gamespot.com/reviews/sports-story-review-over-par/1900-6418016/ saved to 'scraped_data.csv'. 154.6.96.78:3128
# 120 Scraped data for https://www.gamespot.com/reviews/high-on-life-review-talking-heads/1900-6418014/ saved to 'scraped_data.csv'. 154.6.96.178:3128
# 121 Scraped data for https://www.gamespot.com/reviews/the-witcher-3-wild-hunt-next-gen-update-review-winds-howlin/1900-6416135/ saved to 'scraped_data.csv'. 154.6.97.183:3128
# 122 Scraped data for https://www.gamespot.com/reviews/dragon-quest-treasures-review-all-about-that-bling/1900-6418012/ saved to 'scraped_data.csv'. 38.62.222.79:3128
# 123 Scraped data for https://www.gamespot.com/reviews/warhammer-40k-darktide-review-left-to-shred/1900-6418008/ saved to 'scraped_data.csv'. 154.6.96.196:3128
# 124 Scraped data for https://www.gamespot.com/reviews/need-for-speed-unbound-review-comic-book-racing/1900-6418010/ saved to 'scraped_data.csv'. 38.62.223.171:3128
# 125 Scraped data for https://www.gamespot.com/reviews/crisis-core-final-fantasy-7-reunion-review-conflict-resolved/1900-6418009/ saved to 'scraped_data.csv'. 154.6.98.108:3128
# 126 Scraped data for https://www.gamespot.com/reviews/the-callisto-protocol-review-i-dont-belong-here/1900-6418007/ saved to 'scraped_data.csv'. 38.62.221.61:3128
# 127 Scraped data for https://www.gamespot.com/reviews/marvels-midnight-suns-review-xcom-superhero-squad/1900-6418006/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 128 Scraped data for https://www.gamespot.com/reviews/evil-west-review-undead-redemption/1900-6418004/ saved to 'scraped_data.csv'. 154.6.98.247:3128
# 129 Scraped data for https://www.gamespot.com/reviews/call-of-duty-warzone-2-review-al-mazrah-shines/1900-6418003/ saved to 'scraped_data.csv'. 154.6.97.230:3128
# 130 Scraped data for https://www.gamespot.com/reviews/pokemon-scarlet-violet-review-a-braviary-new-world/1900-6417994/ saved to 'scraped_data.csv'. 38.62.223.231:3128
# 131 Scraped data for https://www.gamespot.com/reviews/the-dark-pictures-anthology-the-devil-in-me-review-holmes-sweet-holmes/1900-6418002/ saved to 'scraped_data.csv'. 38.62.220.3:3128
# 132 Scraped data for https://www.gamespot.com/reviews/marvels-spider-man-miles-morales-review-miles-per-power/1900-6417599/ saved to 'scraped_data.csv'. 154.6.96.196:3128
# 133 Scraped data for https://www.gamespot.com/reviews/somerville-review-i-wanted-to-believe/1900-6417999/ saved to 'scraped_data.csv'. 154.6.96.161:3128
# 134 Scraped data for https://www.gamespot.com/reviews/tactics-ogre-reborn-review-4d-chess/1900-6417997/ saved to 'scraped_data.csv'. 38.62.221.49:3128
# 135 Scraped data for https://www.gamespot.com/reviews/pentiment-review-layers-of-history/1900-6417998/ saved to 'scraped_data.csv'. 154.6.97.112:3128
# 136 Scraped data for https://www.gamespot.com/reviews/sonic-frontiers-review-sonic-is-that-you/1900-6417995/ saved to 'scraped_data.csv'. 154.6.98.9:3128
# 137 Scraped data for https://www.gamespot.com/reviews/god-of-war-ragnarok-review-blood-sweat-and-tyrs/1900-6417993/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# 138 Scraped data for https://www.gamespot.com/reviews/call-of-duty-modern-warfare-2-multiplayer-review-meet-the-new-cod-same-as-the-old-cod/1900-6417992/ saved to 'scraped_data.csv'. 38.62.220.211:3128
# 139 Scraped data for https://www.gamespot.com/reviews/signalis-review-silent-thrill/1900-6417982/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# 140 Scraped data for https://www.gamespot.com/reviews/marvel-snap-review-mccgu/1900-6417991/ saved to 'scraped_data.csv'. 154.6.98.101:3128
# 141 Scraped data for https://www.gamespot.com/reviews/ghostbusters-spirits-unleashed-review-into-the-ether/1900-6417990/ saved to 'scraped_data.csv'. 38.62.220.114:3128
# An error occurred with proxy 38.62.223.128:3128 while scraping https://www.gamespot.com/reviews/bayonetta-3-review-real-hot-girls-hit/1900-6417989/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/bayonetta-3-review-real-hot-girls-hit/1900-6417989/.
# 142 Scraped data for https://www.gamespot.com/reviews/resident-evil-village-winters-expansion-review-this-rose-doesnt-bloom/1900-6417988/ saved to 'scraped_data.csv'. 38.62.223.173:3128
# 143 Scraped data for https://www.gamespot.com/reviews/call-of-duty-modern-warfare-2-campaign-review-just-like-old-times/1900-6417987/ saved to 'scraped_data.csv'. 38.62.223.171:3128
# 144 Scraped data for https://www.gamespot.com/reviews/mario-rabbids-sparks-of-hope-review-this-sparks-joy/1900-6417985/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 145 Scraped data for https://www.gamespot.com/reviews/new-tales-from-the-borderlands-review-good-stories/1900-6417984/ saved to 'scraped_data.csv'. 38.62.221.64:3128
# 146 Scraped data for https://www.gamespot.com/reviews/gotham-knights-review-knightfall/1900-6417983/ saved to 'scraped_data.csv'. 38.62.222.254:3128
# 147 Scraped data for https://www.gamespot.com/reviews/uncharted-legacy-of-thieves-review-charted-again/1900-6417817/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 148 Scraped data for https://www.gamespot.com/reviews/a-plague-tale-requiem-review-picturesque-terror/1900-6417981/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 149 Scraped data for https://www.gamespot.com/reviews/scorn-review-pound-of-flesh/1900-6417976/ saved to 'scraped_data.csv'. 154.6.97.230:3128
# 150 Scraped data for https://www.gamespot.com/reviews/pga-tour-2k23-review-links-to-the-future/1900-6417979/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 151 Scraped data for https://www.gamespot.com/reviews/grounded-review-mountains-out-of-molehills/1900-6417966/ saved to 'scraped_data.csv'. 154.6.96.102:3128
# 152 Scraped data for https://www.gamespot.com/reviews/overwatch-2-review-same-as-it-ever-was/1900-6417972/ saved to 'scraped_data.csv'. 38.62.220.231:3128
# 153 Scraped data for https://www.gamespot.com/reviews/lego-bricktales-review-build-brick-better/1900-6417978/ saved to 'scraped_data.csv'. 38.62.220.245:3128
# 154 Scraped data for https://www.gamespot.com/reviews/valkyrie-elysium-review-putting-the-mid-in-midgard/1900-6417977/ saved to 'scraped_data.csv'. 154.6.99.215:3128
# 155 Scraped data for https://www.gamespot.com/reviews/fifa-23-review-football-is-life/1900-6417971/ saved to 'scraped_data.csv'. 154.6.99.57:3128
# 156 Scraped data for https://www.gamespot.com/reviews/nier-automata-review/1900-6416628/ saved to 'scraped_data.csv'. 38.62.221.28:3128
# An error occurred with proxy 38.62.223.29:3128 while scraping https://www.gamespot.com/reviews/potion-permit-review-an-engaging-elixir/1900-6417970/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/potion-permit-review-an-engaging-elixir/1900-6417970/.
# 157 Scraped data for https://www.gamespot.com/reviews/desta-the-memories-between-review-dodging-confrontation/1900-6417968/ saved to 'scraped_data.csv'. 38.62.220.17:3128
# 158 Scraped data for https://www.gamespot.com/reviews/hyper-demon-review-slayer/1900-6417967/ saved to 'scraped_data.csv'. 38.62.220.245:3128
# 159 Scraped data for https://www.gamespot.com/reviews/the-diofield-chronicle-review-forever-war/1900-6417963/ saved to 'scraped_data.csv'. 154.6.96.196:3128
# 160 Scraped data for https://www.gamespot.com/reviews/shovel-knight-dig-review-ace-of-spades/1900-6417965/ saved to 'scraped_data.csv'. 154.6.97.53:3128
# 161 Scraped data for https://www.gamespot.com/reviews/return-to-monkey-island-review-happiness-is-a-warm-manatee/1900-6417961/ saved to 'scraped_data.csv'. 38.62.221.174:3128
# 162 Scraped data for https://www.gamespot.com/reviews/splatoon-3-review/1900-6417951/ saved to 'scraped_data.csv'. 38.62.221.4:3128
# An error occurred with proxy 38.62.222.89:3128 while scraping https://www.gamespot.com/reviews/tinykin-review-a-charming-collectathon-callback/1900-6417959/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/tinykin-review-a-charming-collectathon-callback/1900-6417959/.
# 163 Scraped data for https://www.gamespot.com/reviews/nba-2k23-review-like-mike/1900-6417958/ saved to 'scraped_data.csv'. 154.6.98.247:3128
# 164 Scraped data for https://www.gamespot.com/reviews/metal-hellsinger-review-walk-with-me-in-hell/1900-6417955/ saved to 'scraped_data.csv'. 38.62.220.114:3128
# 165 Scraped data for https://www.gamespot.com/reviews/kirbys-dream-buffet-review-good-food-tiny-portions/1900-6417954/ saved to 'scraped_data.csv'. 154.6.99.215:3128
# 166 Scraped data for https://www.gamespot.com/reviews/steelrising-review-like-clockwork/1900-6417953/ saved to 'scraped_data.csv'. 154.6.98.196:3128
# 167 Scraped data for https://www.gamespot.com/reviews/immortality-review-a-most-unusual-camera/1900-6417948/ saved to 'scraped_data.csv'. 38.62.220.194:3128
# 168 Scraped data for https://www.gamespot.com/reviews/madden-nfl-23-review-high-upside/1900-6417946/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 169 Scraped data for https://www.gamespot.com/reviews/jetpack-joyride-2-review-running-up-that-hall/1900-6417947/ saved to 'scraped_data.csv'. 154.6.99.215:3128
# 170 Scraped data for https://www.gamespot.com/reviews/saints-row-review-open-world-nostalgia/1900-6417945/ saved to 'scraped_data.csv'. 38.62.223.141:3128
# 171 Scraped data for https://www.gamespot.com/reviews/midnight-fight-express-review-streets-of-rage/1900-6417941/ saved to 'scraped_data.csv'. 154.6.99.49:3128
# 172 Scraped data for https://www.gamespot.com/reviews/soul-hackers-2-review-amateurs-hack-systems-professionals-hack-people/1900-6417943/ saved to 'scraped_data.csv'. 38.62.220.202:3128
# 173 Scraped data for https://www.gamespot.com/reviews/cursed-to-golf-review-an-ace-in-the-hole/1900-6417942/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 174 Scraped data for https://www.gamespot.com/reviews/we-are-ofk-review-acoustic-resonance/1900-6417939/ saved to 'scraped_data.csv'. 38.62.221.140:3128
# 175 Scraped data for https://www.gamespot.com/reviews/rollerdrome-review-skate-or-die/1900-6417938/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 176 Scraped data for https://www.gamespot.com/reviews/thymesia-review-hunter-homage/1900-6417937/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 177 Scraped data for https://www.gamespot.com/reviews/digimon-survive-review-digital-devolution/1900-6417936/ saved to 'scraped_data.csv'. 154.6.96.78:3128
# 178 Scraped data for https://www.gamespot.com/reviews/marvels-spider-man-review-amazing-fantasy/1900-6416975/ saved to 'scraped_data.csv'. 38.62.221.28:3128
# 179 Scraped data for https://www.gamespot.com/reviews/cult-of-the-lamb-review-a-cult-classic/1900-6417933/ saved to 'scraped_data.csv'. 154.6.98.169:3128
# 180 Scraped data for https://www.gamespot.com/reviews/multiversus-review-a-super-smash-hit/1900-6417930/ saved to 'scraped_data.csv'. 154.6.98.196:3128
# 181 Scraped data for https://www.gamespot.com/reviews/hard-west-2-review-bouncing-back/1900-6417931/ saved to 'scraped_data.csv'. 38.62.223.173:3128
# 182 Scraped data for https://www.gamespot.com/reviews/two-point-campus-review-old-school/1900-6417929/ saved to 'scraped_data.csv'. 38.62.222.79:3128
# 183 Scraped data for https://www.gamespot.com/reviews/river-city-saga-three-kingdoms-review-dynasty-brawlers/1900-6417925/ saved to 'scraped_data.csv'. 154.6.99.215:3128
# 184 Scraped data for https://www.gamespot.com/reviews/bear-and-breakfast-review-four-star-stay/1900-6417924/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 185 Scraped data for https://www.gamespot.com/reviews/forza-horizon-5-hot-wheels-review-paradise-city/1900-6417922/ saved to 'scraped_data.csv'. 38.62.221.176:3128
# 186 Scraped data for https://www.gamespot.com/reviews/powerwash-simulator-review-filthy-rich/1900-6417923/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 187 Scraped data for https://www.gamespot.com/reviews/into-the-breach-advanced-edition-review-a-mechanized-masterpiece/1900-6416865/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# 188 Scraped data for https://www.gamespot.com/reviews/xenoblade-chronicles-3-review-masters-of-war/1900-6417921/ saved to 'scraped_data.csv'. 154.6.96.231:3128
# 189 Scraped data for https://www.gamespot.com/reviews/live-a-live-review-live-laugh-love-live-a-live/1900-6417919/ saved to 'scraped_data.csv'. 154.6.99.105:3128
# 190 Scraped data for https://www.gamespot.com/reviews/air-twister-review-repetitious-fantasy/1900-6417918/ saved to 'scraped_data.csv'. 154.6.98.196:3128
# 191 Scraped data for https://www.gamespot.com/reviews/stray-review-nine-lives/1900-6417917/ saved to 'scraped_data.csv'. 154.6.97.73:3128
# 192 Scraped data for https://www.gamespot.com/reviews/poinpy-review-moving-on-up/1900-6417902/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 193 Scraped data for https://www.gamespot.com/reviews/monster-hunter-rise-sunbreak-review-sunrise-over-the-kingdom/1900-6417916/ saved to 'scraped_data.csv'. 154.6.98.203:3128
# 194 Scraped data for https://www.gamespot.com/reviews/as-dusk-falls-review-family-matters/1900-6417915/ saved to 'scraped_data.csv'. 154.6.97.183:3128
# 195 Scraped data for https://www.gamespot.com/reviews/escape-academy-review-im-an-a-student/1900-6417914/ saved to 'scraped_data.csv'. 154.6.98.41:3128
# 196 Scraped data for https://www.gamespot.com/reviews/olliolli-world-void-riders-review-extra-dimensions/1900-6417911/ saved to 'scraped_data.csv'. 38.62.221.61:3128
# 197 Scraped data for https://www.gamespot.com/reviews/arcadegeddon-review-a-dubstep-in-the-wrong-direction/1900-6417912/ saved to 'scraped_data.csv'. 154.6.97.10:3128
# 198 Scraped data for https://www.gamespot.com/reviews/f1-22-review-hammer-time/1900-6417910/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# 199 Scraped data for https://www.gamespot.com/reviews/outriders-worldslayer-review-pleasantly-altered/1900-6417907/ saved to 'scraped_data.csv'. 154.6.98.205:3128
# 200 Scraped data for https://www.gamespot.com/reviews/dnf-duel-review-here-comes-a-new-challenger/1900-6417906/ saved to 'scraped_data.csv'. 38.62.223.109:3128
# 201 Scraped data for https://www.gamespot.com/reviews/nintendo-switch-sports-review-better-together/1900-6417867/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# 202 Scraped data for https://www.gamespot.com/reviews/tunic-review-fox-die/1900-6417845/ saved to 'scraped_data.csv'. 154.6.96.78:3128
# 203 Scraped data for https://www.gamespot.com/reviews/cuphead-the-delicious-last-course-review-more-than-a-cherry-on-top/1900-6417904/ saved to 'scraped_data.csv'. 154.6.98.169:3128
# 204 Scraped data for https://www.gamespot.com/reviews/neon-white-review-heavenly-sprint/1900-6417905/ saved to 'scraped_data.csv'. 38.62.221.4:3128
# 205 Scraped data for https://www.gamespot.com/reviews/capcom-fighting-collection-review-family-feud/1900-6417898/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# 206 Scraped data for https://www.gamespot.com/reviews/disney-mirrorverse-review-shattered-dreams/1900-6417901/ saved to 'scraped_data.csv'. 154.6.98.9:3128
# 207 Scraped data for https://www.gamespot.com/reviews/sonic-origins-review-going-fast-again/1900-6417900/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 208 Scraped data for https://www.gamespot.com/reviews/diablo-immortal-review-evil-on-the-go/1900-6417897/ saved to 'scraped_data.csv'. 38.62.220.231:3128
# 209 Scraped data for https://www.gamespot.com/reviews/fire-emblem-warriors-three-hopes-review-wars-with-friends/1900-6417899/ saved to 'scraped_data.csv'. 38.62.220.232:3128
# 210 Scraped data for https://www.gamespot.com/reviews/teenage-mutant-ninja-turtles-shredders-revenge-review-turtle-power/1900-6417895/ saved to 'scraped_data.csv'. 154.6.99.233:3128
# 211 Scraped data for https://www.gamespot.com/reviews/mario-strikers-battle-league-review/1900-6417891/ saved to 'scraped_data.csv'. 38.62.220.245:3128
# 212 Scraped data for https://www.gamespot.com/reviews/the-quarry-review-summer-scare-fest/1900-6417892/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# 213 Scraped data for https://www.gamespot.com/reviews/roller-champions-review-keep-rollin-rollin-rollin/1900-6417889/ saved to 'scraped_data.csv'. 154.6.98.39:3128
# 214 Scraped data for https://www.gamespot.com/reviews/halo-infinite-multiplayer-review-i-need-a-weapon/1900-6417793/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 215 Scraped data for https://www.gamespot.com/reviews/soundfall-review-not-quite-my-tempo/1900-6417887/ saved to 'scraped_data.csv'. 154.6.97.22:3128
# 216 Scraped data for https://www.gamespot.com/reviews/apex-legends-mobile-review-pocket-sized-royale/1900-6417885/ saved to 'scraped_data.csv'. 38.62.223.141:3128
# 217 Scraped data for https://www.gamespot.com/reviews/hatsune-miku-project-diva-megamix-review-the-most-miku/1900-6417886/ saved to 'scraped_data.csv'. 38.62.223.187:3128
# 218 Scraped data for https://www.gamespot.com/reviews/sniper-elite-5-review-longer-range/1900-6417884/ saved to 'scraped_data.csv'. 154.6.98.166:3128
# 219 Scraped data for https://www.gamespot.com/reviews/evil-dead-the-game-review-somewhat-groovy/1900-6417881/ saved to 'scraped_data.csv'. 154.6.96.197:3128
# 220 Scraped data for https://www.gamespot.com/reviews/vampire-the-masquerade-swansong-review-that-sinking-feeling/1900-6417882/ saved to 'scraped_data.csv'. 154.6.98.195:3128
# 221 Scraped data for https://www.gamespot.com/reviews/salt-and-sacrifice-review-mage-hunter/1900-6417879/ saved to 'scraped_data.csv'. 154.6.98.222:3128
# 222 Scraped data for https://www.gamespot.com/reviews/eiyuden-chronicle-rising-review-humble-beginnings/1900-6417878/ saved to 'scraped_data.csv'. 154.6.98.23:3128
# 223 Scraped data for https://www.gamespot.com/reviews/trek-to-yomi-review-one-samurai/1900-6417874/ saved to 'scraped_data.csv'. 154.6.96.161:3128
# 224 Scraped data for https://www.gamespot.com/reviews/rifftrax-the-game-review-dumb-jokes-reign-supreme/1900-6417875/ saved to 'scraped_data.csv'. 38.62.221.46:3128
# 225 Scraped data for https://www.gamespot.com/reviews/gotta-protectors-cart-of-darkness-lets-protectorize-guys/1900-6417873/ saved to 'scraped_data.csv'. 154.6.96.231:3128
# 226 Scraped data for https://www.gamespot.com/reviews/teardown-review-came-in-like-a-wrecking-ball/1900-6417871/ saved to 'scraped_data.csv'. 154.6.99.105:3128
# 227 Scraped data for https://www.gamespot.com/reviews/rogue-legacy-2-review-grand-lineage/1900-6417870/ saved to 'scraped_data.csv'. 38.62.223.187:3128
# 228 Scraped data for https://www.gamespot.com/reviews/bugsnax-the-isle-of-bigsnax-review-secret-menu/1900-6417869/ saved to 'scraped_data.csv'. 154.6.99.215:3128
# 229 Scraped data for https://www.gamespot.com/reviews/the-stanley-parable-ultra-deluxe-review-a-sequel-in-all-but-name/1900-6417868/ saved to 'scraped_data.csv'. 38.62.223.189:3128
# 230 Scraped data for https://www.gamespot.com/reviews/back-4-blood-tunnels-of-terror-dlc-review/1900-6417865/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# 231 Scraped data for https://www.gamespot.com/reviews/road-96-review-i-would-walk-500-miles/1900-6417866/ saved to 'scraped_data.csv'. 38.62.221.74:3128
# 232 Scraped data for https://www.gamespot.com/reviews/postal-4-no-regerts-review-nothing-but-regrets/1900-6417864/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# 233 Scraped data for https://www.gamespot.com/reviews/cat-cafe-manager-review-meow-were-in-business/1900-6417863/ saved to 'scraped_data.csv'. 38.62.223.171:3128
# 234 Scraped data for https://www.gamespot.com/reviews/norco-review-deep-south-dystopia/1900-6417861/ saved to 'scraped_data.csv'. 154.6.96.231:3128
# 235 Scraped data for https://www.gamespot.com/reviews/lego-star-wars-the-skywalker-saga-review-duel-of-the-bricks/1900-6417859/ saved to 'scraped_data.csv'. 38.62.222.254:3128
# 236 Scraped data for https://www.gamespot.com/reviews/13-sentinels-aegis-rim-review-wow-cool-robot/1900-6417569/ saved to 'scraped_data.csv'. 154.6.97.73:3128
# 237 Scraped data for https://www.gamespot.com/reviews/mlb-the-show-22-review-its-shotime/1900-6417858/ saved to 'scraped_data.csv'. 154.6.97.200:3128
# 238 Scraped data for https://www.gamespot.com/reviews/chinatown-detective-agency-review-carmen-singapore/1900-6417856/ saved to 'scraped_data.csv'. 38.62.220.194:3128
# 239 Scraped data for https://www.gamespot.com/reviews/weird-west-review-occult-of-personality/1900-6417853/ saved to 'scraped_data.csv'. 38.62.223.29:3128
# An error occurred with proxy 154.6.99.255:3128 while scraping https://www.gamespot.com/reviews/tiny-tinas-wonderlands-review-spells-like-teen-spirit/1900-6417849/: HTTPSConnectionPool(host='www.gamespot.com', port=443): Max retries exceeded with url: /reviews/tiny-tinas-wonderlands-review-spells-like-teen-spirit/1900-6417849/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000027D24CACE10>, 'Connection to 154.6.99.255 timed out. (connect timeout=None)'))
# Failed to scrape data for https://www.gamespot.com/reviews/tiny-tinas-wonderlands-review-spells-like-teen-spirit/1900-6417849/.
# 240 Scraped data for https://www.gamespot.com/reviews/kirby-and-the-forgotten-land-review-the-best-kirby-yet/1900-6417850/ saved to 'scraped_data.csv'. 38.62.221.46:3128
# 241 Scraped data for https://www.gamespot.com/reviews/ghostwire-tokyo-review-shibuya-scramble/1900-6417848/ saved to 'scraped_data.csv'. 154.6.98.108:3128
# 242 Scraped data for https://www.gamespot.com/reviews/wwe-2k22-review-bad-times-dont-last/1900-6417846/ saved to 'scraped_data.csv'. 154.6.98.167:3128
# 243 Scraped data for https://www.gamespot.com/reviews/elden-ring-review-death-of-the-wild/1900-6417832/ saved to 'scraped_data.csv'. 38.62.220.3:3128
# 244 Scraped data for https://www.gamespot.com/reviews/stranger-of-paradise-final-fantasy-origin-review-chaos-incarnate/1900-6417844/ saved to 'scraped_data.csv'. 38.62.222.67:3128
# 245 Scraped data for https://www.gamespot.com/reviews/triangle-strategy-review-were-talking-kings-and-successions/1900-6417840/ saved to 'scraped_data.csv'. 38.62.221.64:3128
# 246 Scraped data for https://www.gamespot.com/reviews/destiny-2-the-witch-queen-review-queens-gambit/1900-6417838/ saved to 'scraped_data.csv'. 38.62.221.140:3128
# 247 Scraped data for https://www.gamespot.com/reviews/assassins-creed-valhalla-dawn-of-ragnarok-review-having-a-good-time/1900-6417841/ saved to 'scraped_data.csv'. 38.62.223.173:3128
# 248 Scraped data for https://www.gamespot.com/reviews/puzzle-quest-3-review-more-puzzle-less-quest/1900-6417842/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# 249 Scraped data for https://www.gamespot.com/reviews/gran-turismo-7-review-round-we-go-again/1900-6417837/ saved to 'scraped_data.csv'. 154.6.96.187:3128
# 250 Scraped data for https://www.gamespot.com/reviews/total-war-warhammer-3-review-bed-of-chaos/1900-6417839/ saved to 'scraped_data.csv'. 38.62.220.211:3128
# 251 Scraped data for https://www.gamespot.com/reviews/lost-ark-review-whyd-it-have-to-be-snakes/1900-6417834/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# 252 Scraped data for https://www.gamespot.com/reviews/land-of-screens-review-short-sweet-but-not-so-subtle/1900-6417833/ saved to 'scraped_data.csv'. 38.62.222.69:3128
# 253 Scraped data for https://www.gamespot.com/reviews/final-fantasy-7-the-first-soldier-review-straining-at-the-seams/1900-6417831/ saved to 'scraped_data.csv'. 154.6.99.233:3128
# 254 Scraped data for https://www.gamespot.com/reviews/the-king-of-fighters-xv-review-wanna-play-some-kof/1900-6417830/ saved to 'scraped_data.csv'. 38.62.221.61:3128
# 255 Scraped data for https://www.gamespot.com/reviews/grapple-dog-review-bionic-commandog/1900-6417829/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 256 Scraped data for https://www.gamespot.com/reviews/horizon-forbidden-west-review/1900-6417826/ saved to 'scraped_data.csv'. 154.6.99.233:3128
# 257 Scraped data for https://www.gamespot.com/reviews/dying-light-2-review-look-before-you-leap/1900-6417819/ saved to 'scraped_data.csv'. 154.6.98.196:3128
# 258 Scraped data for https://www.gamespot.com/reviews/sifu-review-i-know-kung-fu/1900-6417823/ saved to 'scraped_data.csv'. 38.62.220.231:3128
# 259 Scraped data for https://www.gamespot.com/reviews/olliolli-world-review-half-pipe-heaven/1900-6417822/ saved to 'scraped_data.csv'. 154.6.96.102:3128
# 260 Scraped data for https://www.gamespot.com/reviews/pokemon-legends-arceus-review-what-pokemon-is-evolving/1900-6417818/ saved to 'scraped_data.csv'. 38.62.221.140:3128
# 261 Scraped data for https://www.gamespot.com/reviews/pupperazzi-review-more-rough-than-ruff/1900-6417816/ saved to 'scraped_data.csv'. 154.6.98.196:3128
# 262 Scraped data for https://www.gamespot.com/reviews/windjammers-2-review-spin-to-win/1900-6417815/ saved to 'scraped_data.csv'. 38.62.223.231:3128
# 263 Scraped data for https://www.gamespot.com/reviews/rainbow-six-extraction-review-breach-and-clear/1900-6417814/ saved to 'scraped_data.csv'. 38.62.223.187:3128
# 264 Scraped data for https://www.gamespot.com/reviews/nobody-saves-the-world-review-creature-comforts/1900-6417812/ saved to 'scraped_data.csv'. 154.6.97.22:3128
# 265 Scraped data for https://www.gamespot.com/reviews/rocket-league-sideswipe-review-pocket-rocket/1900-6417809/ saved to 'scraped_data.csv'. 38.62.223.109:3128
# 266 Scraped data for https://www.gamespot.com/reviews/god-of-war-review-out-with-the-old-in-with-the-new/1900-6416893/ saved to 'scraped_data.csv'. 38.62.222.69:3128
# 267 Scraped data for https://www.gamespot.com/reviews/monster-hunter-rise-review-standing-tall/1900-6417652/ saved to 'scraped_data.csv'. 38.62.223.171:3128
# 268 Scraped data for https://www.gamespot.com/reviews/the-gunk-review-all-gunked-up/1900-6417807/ saved to 'scraped_data.csv'. 38.62.221.155:3128
# 269 Scraped data for https://www.gamespot.com/reviews/final-fantasy-xiv-endwalker-review-that-i-cant-deny/1900-6417806/ saved to 'scraped_data.csv'. 38.62.223.137:3128
# 270 Scraped data for https://www.gamespot.com/reviews/ruined-king-a-league-of-legends-story-review-we-are-the-champions/1900-6417802/ saved to 'scraped_data.csv'. 154.6.98.247:3128
# An error occurred with proxy 38.62.220.17:3128 while scraping https://www.gamespot.com/reviews/shovel-knight-pocket-dungeon-review-dig-deep/1900-6417800/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/shovel-knight-pocket-dungeon-review-dig-deep/1900-6417800/.
# 271 Scraped data for https://www.gamespot.com/reviews/halo-infinite-campaign-review-what-if-master-chief-was-daddy/1900-6417798/ saved to 'scraped_data.csv'. 38.62.222.62:3128
# 272 Scraped data for https://www.gamespot.com/reviews/big-brain-academy-brain-vs-brain-review/1900-6417796/ saved to 'scraped_data.csv'. 154.6.97.73:3128
# 273 Scraped data for https://www.gamespot.com/reviews/solar-ash-review-ash-wins-day/1900-6417797/ saved to 'scraped_data.csv'. 38.62.223.141:3128
# 274 Scraped data for https://www.gamespot.com/reviews/pokemon-brilliant-diamond-shining-pearl-review/1900-6417790/ saved to 'scraped_data.csv'. 154.6.97.10:3128
# 275 Scraped data for https://www.gamespot.com/reviews/battlefield-2042-review-character-development/1900-6417785/ saved to 'scraped_data.csv'. 38.62.220.231:3128
# 276 Scraped data for https://www.gamespot.com/reviews/sherlock-holmes-chapter-one-review-murder-in-the-mediterranean/1900-6417792/ saved to 'scraped_data.csv'. 38.62.220.232:3128
# 277 Scraped data for https://www.gamespot.com/reviews/grand-theft-auto-the-trilogy-definitive-edition-review-wasted/1900-6417791/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 278 Scraped data for https://www.gamespot.com/reviews/inscryption-review-house-of-cards/1900-6417788/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 279 Scraped data for https://www.gamespot.com/reviews/new-world-review-faction-war-never-changes/1900-6417769/ saved to 'scraped_data.csv'. 154.6.96.102:3128
# ...
# 2243 Scraped data for https://www.gamespot.com/reviews/dragons-dogma-dark-arisen-review/1900-6407493/ saved to 'scraped_data.csv'. 154.6.98.108:3128
# 2244 Scraped data for https://www.gamespot.com/reviews/dark-review/1900-6412133/ saved to 'scraped_data.csv'. 154.6.98.41:3128
# 2245 Scraped data for https://www.gamespot.com/reviews/far-cry-3-blood-dragon-review/1900-6407627/ saved to 'scraped_data.csv'. 154.6.97.112:3128
# 2246 Scraped data for https://www.gamespot.com/reviews/far-cry-3-blood-dragon-review/1900-6407642/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# 2247 Scraped data for https://www.gamespot.com/reviews/deadpool-review/1900-6410731/ saved to 'scraped_data.csv'. 154.6.96.178:3128
# 2248 Scraped data for https://www.gamespot.com/reviews/remember-me-review/1900-6409148/ saved to 'scraped_data.csv'. 154.6.96.78:3128
# 2249 Scraped data for https://www.gamespot.com/reviews/remember-me-review/1900-6409150/ saved to 'scraped_data.csv'. 38.62.221.176:3128
# 2250 Scraped data for https://www.gamespot.com/reviews/remember-me-review/1900-6409154/ saved to 'scraped_data.csv'. 154.6.97.183:3128
# 2251 Scraped data for https://www.gamespot.com/reviews/naruto-shippuden-ultimate-ninja-storm-3-review/1900-6405027/ saved to 'scraped_data.csv'. 154.6.97.49:3128
# 2252 Scraped data for https://www.gamespot.com/reviews/naruto-shippuden-ultimate-ninja-storm-3-review/1900-6405034/ saved to 'scraped_data.csv'. 154.6.96.208:3128
# 2253 Scraped data for https://www.gamespot.com/reviews/starcraft-ii-heart-of-the-swarm-review/1900-6405683/ saved to 'scraped_data.csv'. 154.6.98.9:3128
# 2254 Scraped data for https://www.gamespot.com/reviews/crysis-3-review/1900-6404063/ saved to 'scraped_data.csv'. 154.6.99.91:3128
# 2255 Scraped data for https://www.gamespot.com/reviews/crysis-3-review/1900-6404074/ saved to 'scraped_data.csv'. 154.6.98.9:3128
# 2256 Scraped data for https://www.gamespot.com/reviews/crysis-3-review/1900-6404083/ saved to 'scraped_data.csv'. 38.62.222.169:3128
# An error occurred with proxy 38.62.222.44:3128 while scraping https://www.gamespot.com/reviews/dmc-devil-may-cry-vergils-downfall-review/1900-6405751/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/dmc-devil-may-cry-vergils-downfall-review/1900-6405751/.
# 2257 Scraped data for https://www.gamespot.com/reviews/dmc-devil-may-cry-review/1900-6402476/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 2258 Scraped data for https://www.gamespot.com/reviews/dmc-devil-may-cry-review/1900-6402276/ saved to 'scraped_data.csv'. 154.6.97.53:3128
# 2259 Scraped data for https://www.gamespot.com/reviews/god-of-war-ascension-review/1900-6404941/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# 2260 Scraped data for https://www.gamespot.com/reviews/grid-2-review/1900-6408978/ saved to 'scraped_data.csv'. 38.62.221.74:3128
# 2261 Scraped data for https://www.gamespot.com/reviews/lego-city-undercover-review/1900-6405211/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# An error occurred with proxy 154.6.97.183:3128 while scraping https://www.gamespot.com/reviews/devil-summoner-soul-hackers-review/1900-6407296/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/devil-summoner-soul-hackers-review/1900-6407296/.
# 2262 Scraped data for https://www.gamespot.com/reviews/dishonored-review/1900-6397794/ saved to 'scraped_data.csv'. 154.6.97.49:3128
# 2263 Scraped data for https://www.gamespot.com/reviews/dishonored-review/1900-6397798/ saved to 'scraped_data.csv'. 154.6.96.208:3128
# 2264 Scraped data for https://www.gamespot.com/reviews/dishonored-review/1900-6397799/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# 2265 Scraped data for https://www.gamespot.com/reviews/dishonored-the-knife-of-dunwall-review/1900-6407364/ saved to 'scraped_data.csv'. 154.6.98.101:3128
# 2266 Scraped data for https://www.gamespot.com/reviews/dishonored-the-knife-of-dunwall-review/1900-6407365/ saved to 'scraped_data.csv'. 154.6.97.10:3128
# 2267 Scraped data for https://www.gamespot.com/reviews/dishonored-the-knife-of-dunwall-review/1900-6407367/ saved to 'scraped_data.csv'. 38.62.223.187:3128
# An error occurred with proxy 154.6.97.200:3128 while scraping https://www.gamespot.com/reviews/mortal-kombat-komplete-edition-review/1900-6411497/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/mortal-kombat-komplete-edition-review/1900-6411497/.
# 2268 Scraped data for https://www.gamespot.com/reviews/ni-no-kuni-wrath-of-the-white-witch-review/1900-6402702/ saved to 'scraped_data.csv'. 38.62.223.231:3128
# 2269 Scraped data for https://www.gamespot.com/reviews/strike-suit-zero-review/1900-6402806/ saved to 'scraped_data.csv'. 154.6.98.132:3128
# An error occurred with proxy 38.62.223.173:3128 while scraping https://www.gamespot.com/reviews/shin-megami-tensei-iv-review/1900-6411458/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/shin-megami-tensei-iv-review/1900-6411458/.
# 2270 Scraped data for https://www.gamespot.com/reviews/company-of-heroes-2-review/1900-6410716/ saved to 'scraped_data.csv'. 38.62.221.49:3128
# An error occurred with proxy 154.6.96.178:3128 while scraping https://www.gamespot.com/reviews/state-of-decay-review/1900-6410413/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/state-of-decay-review/1900-6410413/.
# An error occurred with proxy 154.6.98.125:3128 while scraping https://www.gamespot.com/reviews/monster-hunter-3-ultimate-review/1900-6405360/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/monster-hunter-3-ultimate-review/1900-6405360/.
# 2271 Scraped data for https://www.gamespot.com/reviews/monster-hunter-3-ultimate-review/1900-6405362/ saved to 'scraped_data.csv'. 154.6.97.188:3128
# 2272 Scraped data for https://www.gamespot.com/reviews/injustice-gods-among-us-review/1900-6407011/ saved to 'scraped_data.csv'. 38.62.222.69:3128
# 2273 Scraped data for https://www.gamespot.com/reviews/injustice-gods-among-us-review/1900-6407055/ saved to 'scraped_data.csv'. 38.62.221.49:3128
# An error occurred with proxy 154.6.99.105:3128 while scraping https://www.gamespot.com/reviews/dead-space-3-awakened-review/1900-6405673/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/dead-space-3-awakened-review/1900-6405673/.
# 2274 Scraped data for https://www.gamespot.com/reviews/dead-space-3-review/1900-6403380/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 2275 Scraped data for https://www.gamespot.com/reviews/dead-space-3-review/1900-6403319/ saved to 'scraped_data.csv'. 154.6.98.148:3128
# An error occurred with proxy 154.6.98.148:3128 while scraping https://www.gamespot.com/reviews/spelunky-review/1900-6412988/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/spelunky-review/1900-6412988/.
# An error occurred with proxy 38.62.222.62:3128 while scraping https://www.gamespot.com/reviews/rise-of-the-triad-review/1900-6412408/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/rise-of-the-triad-review/1900-6412408/.
# 2276 Scraped data for https://www.gamespot.com/reviews/mario-and-luigi-dream-team-review/1900-6411220/ saved to 'scraped_data.csv'. 38.62.223.128:3128
# 2277 Scraped data for https://www.gamespot.com/reviews/killer-is-dead-review/1900-6413067/ saved to 'scraped_data.csv'. 154.6.98.167:3128
# 2278 Scraped data for https://www.gamespot.com/reviews/shadowrun-returns-review/1900-6412261/ saved to 'scraped_data.csv'. 154.6.98.108:3128
# 2279 Scraped data for https://www.gamespot.com/reviews/dragons-crown-review/1900-6412299/ saved to 'scraped_data.csv'. 154.6.97.42:3128
# An error occurred with proxy 154.6.97.188:3128 while scraping https://www.gamespot.com/reviews/shelter-review/1900-6414002/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/shelter-review/1900-6414002/.
# An error occurred with proxy 38.62.222.254:3128 while scraping https://www.gamespot.com/reviews/spycraft-the-great-game-review/1900-2533149/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/spycraft-the-great-game-review/1900-2533149/.
# An error occurred with proxy 154.6.97.213:3128 while scraping https://www.gamespot.com/reviews/open-me-review/1900-6413127/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/open-me-review/1900-6413127/.
# 2280 Scraped data for https://www.gamespot.com/reviews/warframe-review-2013/1900-6412471/ saved to 'scraped_data.csv'. 154.6.98.41:3128
# 2281 Scraped data for https://www.gamespot.com/reviews/pikmin-3-review/1900-6412256/ saved to 'scraped_data.csv'. 154.6.96.139:3128
# 2282 Scraped data for https://www.gamespot.com/reviews/stealth-inc-a-clone-in-the-dark-review/1900-6411880/ saved to 'scraped_data.csv'. 154.6.96.208:3128
# An error occurred with proxy 38.62.223.189:3128 while scraping https://www.gamespot.com/reviews/time-and-eternity-review/1900-6411775/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/time-and-eternity-review/1900-6411775/.
# An error occurred with proxy 154.6.96.208:3128 while scraping https://www.gamespot.com/reviews/guncraft-review/1900-6411685/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/guncraft-review/1900-6411685/.
# 2283 Scraped data for https://www.gamespot.com/reviews/pacific-rim-review/1900-6411616/ saved to 'scraped_data.csv'. 154.6.97.183:3128
# An error occurred with proxy 154.6.97.42:3128 while scraping https://www.gamespot.com/reviews/bleed-review/1900-6411380/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/bleed-review/1900-6411380/.
# 2284 Scraped data for https://www.gamespot.com/reviews/ride-to-hell-retribution-review/1900-6411189/ saved to 'scraped_data.csv'. 38.62.223.192:3128
# An error occurred with proxy 154.6.99.255:3128 while scraping https://www.gamespot.com/reviews/the-last-door-review/1900-6411330/: HTTPSConnectionPool(host='www.gamespot.com', port=443): Max retries exceeded with url: /reviews/the-last-door-review/1900-6411330/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000027D269169D0>, 'Connection to 154.6.99.255 timed out. (connect timeout=None)'))
# Failed to scrape data for https://www.gamespot.com/reviews/the-last-door-review/1900-6411330/.
# 2285 Scraped data for https://www.gamespot.com/reviews/ncaa-football-14-review/1900-6411054/ saved to 'scraped_data.csv'. 154.6.99.81:3128
# An error occurred with proxy 154.6.99.215:3128 while scraping https://www.gamespot.com/reviews/project-x-zone-review/1900-6411004/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/project-x-zone-review/1900-6411004/.
# 2286 Scraped data for https://www.gamespot.com/reviews/scourge-outbreak-review/1900-6410953/ saved to 'scraped_data.csv'. 154.6.98.169:3128
# An error occurred with proxy 38.62.220.245:3128 while scraping https://www.gamespot.com/reviews/leisure-suit-larry-reloaded-review/1900-6410868/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/leisure-suit-larry-reloaded-review/1900-6410868/.
# An error occurred with proxy 154.6.98.23:3128 while scraping https://www.gamespot.com/reviews/wargame-airland-battle-review/1900-6410884/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/wargame-airland-battle-review/1900-6410884/.
# 2287 Scraped data for https://www.gamespot.com/reviews/new-super-luigi-u-review/1900-6410778/ saved to 'scraped_data.csv'. 38.62.223.231:3128
# An error occurred with proxy 154.6.98.132:3128 while scraping https://www.gamespot.com/reviews/game-and-wario-review/1900-6410777/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/game-and-wario-review/1900-6410777/.
# An error occurred with proxy 154.6.97.53:3128 while scraping https://www.gamespot.com/reviews/hotline-miami-review/1900-6410677/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/hotline-miami-review/1900-6410677/.
# An error occurred with proxy 154.6.99.91:3128 while scraping https://www.gamespot.com/reviews/magrunner-dark-pulse-review/1900-6410659/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/magrunner-dark-pulse-review/1900-6410659/.
# 2288 Scraped data for https://www.gamespot.com/reviews/kentucky-route-zero-act-ii-review/1900-6410651/ saved to 'scraped_data.csv'. 154.6.97.49:3128
# 2289 Scraped data for https://www.gamespot.com/reviews/marvel-heroes-review/1900-6410615/ saved to 'scraped_data.csv'. 38.62.223.109:3128
# An error occurred with proxy 154.6.97.22:3128 while scraping https://www.gamespot.com/reviews/fist-puncher-review/1900-6410657/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/fist-puncher-review/1900-6410657/.
# An error occurred with proxy 154.6.98.39:3128 while scraping https://www.gamespot.com/reviews/the-night-of-the-rabbit-review/1900-6409482/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/the-night-of-the-rabbit-review/1900-6409482/.
# An error occurred with proxy 154.6.98.166:3128 while scraping https://www.gamespot.com/reviews/7-grand-steps-review/1900-6409420/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/7-grand-steps-review/1900-6409420/.
# An error occurred with proxy 154.6.98.148:3128 while scraping https://www.gamespot.com/reviews/reus-review/1900-6409266/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/reus-review/1900-6409266/.
# An error occurred with proxy 154.6.99.105:3128 while scraping https://www.gamespot.com/reviews/animal-crossing-new-leaf-review/1900-6409125/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/animal-crossing-new-leaf-review/1900-6409125/.
# An error occurred with proxy 38.62.222.108:3128 while scraping https://www.gamespot.com/reviews/rush-bros-review/1900-6409071/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/rush-bros-review/1900-6409071/.
# An error occurred with proxy 154.6.99.49:3128 while scraping https://www.gamespot.com/reviews/denpa-men-2-beyond-the-waves-review/1900-6409034/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/denpa-men-2-beyond-the-waves-review/1900-6409034/.
# An error occurred with proxy 38.62.222.44:3128 while scraping https://www.gamespot.com/reviews/the-swapper-review/1900-6408976/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/the-swapper-review/1900-6408976/.
# 2290 Scraped data for https://www.gamespot.com/reviews/fuse-review/1900-6408841/ saved to 'scraped_data.csv'. 154.6.97.112:3128
# 2291 Scraped data for https://www.gamespot.com/reviews/fuse-review/1900-6408835/ saved to 'scraped_data.csv'. 154.6.96.121:3128
# An error occurred with proxy 38.62.222.62:3128 while scraping https://www.gamespot.com/reviews/renaissance-heroes-review/1900-6408900/: 'NoneType' object has no attribute 'text'
# Failed to scrape data for https://www.gamespot.com/reviews/renaissance-heroes-review/1900-6408900/.
# 2292 Scraped data for https://www.gamespot.com/reviews/resident-evil-revelations-review/1900-6408773/ saved to 'scraped_data.csv'. 154.6.96.45:3128
